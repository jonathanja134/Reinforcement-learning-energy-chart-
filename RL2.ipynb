# %%
import gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gym import spaces
from stable_baselines3 import PPO
import plotly.graph_objects as go
import plotly.express as px
import openpyxl
import random

seed = random.randint(0, 1000000)
print(f"Random seed used for this run: {seed}")

np.random.seed(seed)
random.seed(seed)

import torch
torch.manual_seed(seed)

# -----------------------------------------------
# LOAD EXCEL DATA
# -----------------------------------------------

excel_path = "/Users/administrator/Documents/Christian_meyer_energy_consulting/untitled folder/batterie project 2024 v2.xlsx"
df_excel = pd.read_excel(excel_path, skiprows=16)

production = df_excel["Production (kWh)"].values
prices = df_excel["Euro/MWh"].values

# Quick plot to check:
plt.plot(prices)
plt.title("Loaded prices from Excel")
plt.show()

# -----------------------------------------------
# ENVIRONMENT
# -----------------------------------------------

class BatteryEnv(gym.Env):
    def __init__(self, prices, production,
                 capacity_kwh=500.0,
                 charge_rate=225.0,
                 discharge_rate=225.0,
                 efficiency=0.9):
        super().__init__()
        self.prices = prices
        self.production = production
        self.T = len(prices)
        self.capacity = capacity_kwh
        self.charge_rate = charge_rate
        self.discharge_rate = discharge_rate
        self.eff = efficiency
        self.steps_per_day = 96  # 15-min steps
        self.prev_action = None
        self.prev_price = None
        self.discharge_count = 0
        self.prev_delta_reward = 0.0
        self.delta_reward = 0.0
        
        self.low_price_threshold = np.percentile(prices, 15)
        self.high_price_threshold = np.percentile(prices, 75)
        self.mean_price = np.mean(prices)/1000

        max_price = np.max(prices)
        max_prod = np.max(production)
        self.observation_space = spaces.Box(
            low=np.array([0.0, 0.0, 0.0]),
            high=np.array([max_price, max_prod, 1.0]),
            dtype=np.float32
        )
        self.action_space = spaces.Discrete(3)  # 0: charge, 1: hold, 2: discharge
    def seed(self, seed=None):
        np.random.seed(seed)
        random.seed(seed)
        try:
            import torch
            torch.manual_seed(seed)
        except ImportError:
            pass
    def reset(self):
        self.t = 0
        self.soc = 0.0
        self.total_profit = 0.0
        self.total_soc = 0.0
        self.total_energy_charged = 0.0
        self.total_energy_discharged = 0.0
        self.prev_action = None
        self.prev_price = None
        self.prev_delta_reward = 0.0
        self.discharge_count = 0
        obs = np.array([self.prices[self.t], self.production[self.t], self.soc], dtype=np.float32)
        return obs

    def step(self, action):
        price = self.prices[self.t]
        actual_production = self.production[self.t]
        
        # reset discharge count every 24 hours
        if self.t % self.steps_per_day == 0:
            self.discharge_count = 0
        
        CHARGE = 0
        HOLD = 1
        DISCHARGE = 2

        # Initialize penalty to 0
        penalty = 0

        # Skip step if no production (night)
        if actual_production == 0:
            self.t += 1
            done = self.t >= self.T
            next_price = self.prices[min(self.t, self.T-1)]
            next_prod = self.production[min(self.t, self.T-1)]
            obs = np.array([next_price, next_prod, self.soc], dtype=np.float32)
            info = dict(
                skip=True,
                soc=self.soc,
                reward=0,
                profit=0,
                price=price,
                action="skip",
                cumulative_profit=self.total_profit
            )
            return obs, 0, done, info

        # Otherwise proceed normally
        profit = 0
        energy_charged = 0.0
        energy_discharged = 0.0
        charge_bonus = 0.0
        #bonus = 0.0

        if action == CHARGE:
            available_capacity = self.capacity * (1.0 - self.soc)
            charge_amount = min(self.charge_rate, available_capacity, actual_production)
            energy_charged = charge_amount
            excess_prod = actual_production - charge_amount

            self.soc += (charge_amount / self.capacity) * self.eff
            self.soc = np.clip(self.soc, 0.0, 1.0)

            if price > 0:
                profit += excess_prod * price / 1000
            LOW_PRICE_THRESHOLD = 40
            LOW_PRICE_BONUS = 15.0
            
            if action == CHARGE and (0 < price <= LOW_PRICE_THRESHOLD):
                charge_bonus = LOW_PRICE_BONUS * (LOW_PRICE_THRESHOLD - price) / LOW_PRICE_THRESHOLD
              

        elif action == DISCHARGE:
            available_energy = self.capacity * self.soc
            discharge_amount = min(self.discharge_rate, available_energy)
            energy_discharged = discharge_amount

            revenue_from_discharge = price * discharge_amount/1000
            self.soc -= (discharge_amount / self.capacity) / self.eff
            self.soc = np.clip(self.soc, 0.0, 1.0)

            revenue_from_prod = price * actual_production/1000
            profit += revenue_from_discharge + revenue_from_prod

            #penalty for low price discharge closer to charge price
            

        elif action == HOLD:
            revenue = price * actual_production/1000
            profit += revenue
            #sigma = 10.0
            #bonus = 5*np.exp(-((price - 50) / 2* sigma**2))


    
        reward = profit + charge_bonus 
        #+ bonus

        # Update previous action and price
        self.prev_action = action
        self.prev_price = price

        # Penalty for too mush charge actions
    

        # Normalize reward
        

        # Update total profit
        self.total_profit += profit
        
        self.total_energy_charged += energy_charged
        self.total_energy_discharged += energy_discharged
        self.total_soc += (abs(energy_discharged) + abs(energy_charged))/ self.capacity

        self.t += 1
        done = self.t >= self.T

        next_price = self.prices[min(self.t, self.T-1)]
        next_prod = self.production[min(self.t, self.T-1)]
        obs = np.array([next_price, next_prod, self.soc], dtype=np.float32)

        info = dict(
            soc=self.soc,
            energy_charged=energy_charged,
            energy_discharged=energy_discharged,
            reward=reward,
            price=price,
            action=int(action),
            profit=profit,
            cumulative_profit=self.total_profit,
            yearly_cycle = self.total_soc
        )

        return obs, reward, done, info

# -----------------------------------------------
# TRAIN MODEL
# -----------------------------------------------

env = BatteryEnv(prices, production)
try:
    model = PPO.load("ppo_battery_model_bonus_removed", env=env, verbose=1, seed=seed)
    print("✅ Loaded previous model successfully.")
except FileNotFoundError:
    print("⚠️ No previous model found. Training from scratch.")
model = PPO("MlpPolicy", env, verbose=1, seed=seed)

# Now train
model.learn(total_timesteps=200_000)
model.save("ppo_battery_model_bonus_removed")

print("Training complete.")

# -----------------------------------------------
# EVALUATE TRAINED AGENT
# -----------------------------------------------

obs = env.reset()
records = []

for t in range(len(prices)):
    action, _ = model.predict(obs, deterministic=True)
    next_obs, reward, done, info = env.step(action)

    if info.get("skip", False):
        obs = next_obs
        continue

    records.append({
        "t": t,
        "price": obs[0],
        "production": obs[1],
        "soc": obs[2],
        "action": action,
        "reward": reward,
        "cumulative_profit": info["cumulative_profit"],
        "total_soc": info["yearly_cycle"],
        "energy_charged": info["energy_charged"],
        "energy_discharged": info["energy_discharged"],
    })

    obs = next_obs
    if done:
        break

df = pd.DataFrame(records)
df.to_csv("battery_rl_results.csv", index=False)


# -----------------------------------------------
# PLOT
# -----------------------------------------------

fig1 = go.Figure()
fig1.add_trace(go.Scattergl(
    y=df['cumulative_profit'],
    mode='lines',
    name='Cumulative Profit (€)',
    line=dict(color='blue')
))
fig1.update_layout(
    title='Cumulative Profit over Time',
    yaxis_title='€',
    xaxis_title='1/4 Hour',
    template='plotly_white'
)
fig1.show()

print(f"Final profit with battery: {df['cumulative_profit'].iloc[-1]:,.2f} €")

fig2 = go.Figure()
fig2.add_trace(go.Scattergl(
    x=df["t"],
    y=df["soc"],
    mode='lines',
    name='State of Charge',
    line=dict(color='orange')
))
fig2.update_layout(
    title='Battery State of Charge (SOC) Over Time',
    xaxis_title='1/4 Hour',
    yaxis_title='SOC [0-1]',
    template='plotly_white'
)
fig2.show()

fig6 = go.Figure()
fig6.add_trace(go.Scattergl(
    x=df["t"],
    y=df["total_soc"],
    mode='lines',
    name='Total SOC',
    line=dict(color='purple')
))
fig6.update_layout(
    title='Total State of Charge Over Time',
    xaxis_title='1/4 Hour',
    yaxis_title='cycles number',
    template='plotly_white',
    yaxis=dict(tickformat=".2f"),
)
fig6.show()

fig3 = go.Figure()

# price line
fig3.add_trace(go.Scattergl(
    x=df["t"],
    y=df["price"],
    mode='lines',
    name='Price [€/MWh]',
    line=dict(color='gray')
))

# Charge markers
fig3.add_trace(go.Scattergl(
    x=df.loc[df.action == 0, "t"],
    y=df.loc[df.action == 0, "price"],
    mode='markers',
    marker=dict(color='green', symbol='triangle-up', size=10),
    name='Charge'
))

# Discharge markers
fig3.add_trace(go.Scattergl(
    x=df.loc[df.action == 2, "t"],
    y=df.loc[df.action == 2, "price"],
    mode='markers',
    marker=dict(color='red', symbol='triangle-down', size=10),
    name='Discharge'
))

# Hold markers
fig3.add_trace(go.Scattergl(
    x=df.loc[df.action == 1, "t"],
    y=df.loc[df.action == 1, "price"],
    mode='markers',
    marker=dict(color='grey', symbol='circle', size=6),
    name='Hold'
))

fig3.update_layout(
    title='Market Prices with RL Actions',
    xaxis_title='1/4 Hour',
    yaxis_title='€/MWh',
    legend=dict(y=0.99, x=0.01),
    template='plotly_white'
)
fig3.show()

fig4 = go.Figure()

fig4.add_trace(go.Histogram(
    x=df.loc[df.action == 0, 'price'],
    name='Charge',
    opacity=0.5,
    marker_color='green',
    nbinsx=30
))

fig4.add_trace(go.Histogram(
    x=df.loc[df.action == 2, 'price'],
    name='Discharge',
    opacity=0.5,
    marker_color='red',
    nbinsx=30
))

fig4.add_trace(go.Histogram(
    x=df.loc[df.action == 1, 'price'],
    name='Hold',
    opacity=0.5,
    marker_color='grey',
    nbinsx=30
))

fig4.update_layout(
    barmode='overlay',
    title='Distribution of Prices Triggering Actions',
    xaxis_title='€/MWh',
    yaxis_title='Count',
    template='plotly_white'
)
fig4.show()

final_profit = df['cumulative_profit'].values[-1]
print("\n" + "="*50)
print(f"Final profit WITH battery (RL): €{final_profit:,.2f}")
print("="*50)
print(f"Battery efficiency: {env.eff}")
# Out:
# Random seed used for this run: 881360
# /usr/local/lib/python3.11/site-packages/gym/spaces/box.py:127: UserWarning:
#
# WARN: Box bound precision lowered by casting to float32
#
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ✅ Loaded previous model successfully.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1406 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009784172 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0141      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.6        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00437    |
# |    value_loss           | 139         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009096146 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0877      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 288         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 574         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 873         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009801051 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.077       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 240         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00393    |
# |    value_loss           | 473         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010857031 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0338      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 677         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00649    |
# |    value_loss           | 1.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007896765 |
# |    clip_fraction        | 0.013       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.013       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 686         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00492    |
# |    value_loss           | 1.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010842916 |
# |    clip_fraction        | 0.0744      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0572      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 805         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00863    |
# |    value_loss           | 1.65e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 821         |
# |    iterations           | 8           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009542806 |
# |    clip_fraction        | 0.0191      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0401      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 577         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00487    |
# |    value_loss           | 1.23e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011789846 |
# |    clip_fraction        | 0.0153      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.0505      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00436    |
# |    value_loss           | 2.63e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 800         |
# |    iterations           | 10          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011506675 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.0538      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 676         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00652    |
# |    value_loss           | 1.67e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 797         |
# |    iterations           | 11          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006866659 |
# |    clip_fraction        | 0.0224      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.021       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 2.11e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 797         |
# |    iterations           | 12          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009143816 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.0495      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 749         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00626    |
# |    value_loss           | 2.02e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 13          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008282214 |
# |    clip_fraction        | 0.0147      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.967      |
# |    explained_variance   | 0.0144      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 2.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 791         |
# |    iterations           | 14          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010297095 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.877      |
# |    explained_variance   | 0.0106      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 240         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00809    |
# |    value_loss           | 612         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 15           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0017533269 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.879       |
# |    explained_variance   | 0.0853       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 315          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 657          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 791          |
# |    iterations           | 16           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0020494852 |
# |    clip_fraction        | 0.00483      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.858       |
# |    explained_variance   | 0.173        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 891          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00421     |
# |    value_loss           | 1.02e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 788          |
# |    iterations           | 17           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0027935044 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.874       |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 104          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 437          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.22e+04     |
# | time/                   |              |
# |    fps                  | 786          |
# |    iterations           | 18           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0034776279 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.854       |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 129          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00321     |
# |    value_loss           | 279          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 5.22e+04    |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 19          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.002676014 |
# |    clip_fraction        | 0.0363      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.88       |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.6        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00341    |
# |    value_loss           | 137         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 5.22e+04    |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 20          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010277855 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.803      |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 293         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00828    |
# |    value_loss           | 640         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 5.22e+04    |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 21          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004438324 |
# |    clip_fraction        | 0.0213      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.811      |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 192         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00283    |
# |    value_loss           | 393         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.22e+04     |
# | time/                   |              |
# |    fps                  | 784          |
# |    iterations           | 22           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0042784135 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.812       |
# |    explained_variance   | 0.249        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 259          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00478     |
# |    value_loss           | 872          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.22e+04     |
# | time/                   |              |
# |    fps                  | 784          |
# |    iterations           | 23           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0056858314 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.732       |
# |    explained_variance   | 0.151        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 349          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00384     |
# |    value_loss           | 1.11e+03     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.5e+04   |
# |    ep_rew_mean          | 5.22e+04  |
# | time/                   |           |
# |    fps                  | 782       |
# |    iterations           | 24        |
# |    time_elapsed         | 62        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0047442 |
# |    clip_fraction        | 0.0424    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.774    |
# |    explained_variance   | 0.193     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 865       |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.00401  |
# |    value_loss           | 1.64e+03  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.22e+04     |
# | time/                   |              |
# |    fps                  | 781          |
# |    iterations           | 25           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0043203873 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.714       |
# |    explained_variance   | 0.105        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 629          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 1.4e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 5.22e+04    |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 26          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008610453 |
# |    clip_fraction        | 0.0982      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 545         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00508    |
# |    value_loss           | 1.99e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 5.22e+04    |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 27          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.013868805 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.742      |
# |    explained_variance   | 0.0646      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+03    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00482    |
# |    value_loss           | 2.53e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.22e+04     |
# | time/                   |              |
# |    fps                  | 781          |
# |    iterations           | 28           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0144779235 |
# |    clip_fraction        | 0.17         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.706       |
# |    explained_variance   | 0.0844       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0085      |
# |    value_loss           | 2.54e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 5.22e+04    |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 29          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008533386 |
# |    clip_fraction        | 0.0404      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.0844      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 764         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00324    |
# |    value_loss           | 2.14e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.22e+04     |
# | time/                   |              |
# |    fps                  | 781          |
# |    iterations           | 30           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0025981725 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.711       |
# |    explained_variance   | 0.0825       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 2.03e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.5e+04    |
# |    ep_rew_mean          | 5.22e+04   |
# | time/                   |            |
# |    fps                  | 779        |
# |    iterations           | 31         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.00936368 |
# |    clip_fraction        | 0.0313     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.728     |
# |    explained_variance   | 0.076      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 420        |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.00432   |
# |    value_loss           | 903        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 5.22e+04    |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 32          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.002174382 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.772      |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 251         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.003      |
# |    value_loss           | 576         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 5.22e+04    |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 33          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011581978 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.811      |
# |    explained_variance   | 0.215       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 592         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00447    |
# |    value_loss           | 980         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 5.22e+04    |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 34          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.010204852 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.806      |
# |    explained_variance   | 0.247       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 271         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00292    |
# |    value_loss           | 474         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.9e+04      |
# | time/                   |              |
# |    fps                  | 776          |
# |    iterations           | 35           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0042960662 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.79        |
# |    explained_variance   | 0.252        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 127          |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.003       |
# |    value_loss           | 318          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.9e+04      |
# | time/                   |              |
# |    fps                  | 776          |
# |    iterations           | 36           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0029446925 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.826       |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 93.8         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 199          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 5.9e+04     |
# | time/                   |             |
# |    fps                  | 775         |
# |    iterations           | 37          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011856768 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.733      |
# |    explained_variance   | 0.379       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 213         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00187    |
# |    value_loss           | 666         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.5e+04    |
# |    ep_rew_mean          | 5.9e+04    |
# | time/                   |            |
# |    fps                  | 775        |
# |    iterations           | 38         |
# |    time_elapsed         | 100        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01069055 |
# |    clip_fraction        | 0.0542     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.696     |
# |    explained_variance   | 0.415      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 234        |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00537   |
# |    value_loss           | 457        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.9e+04      |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 39           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0028439225 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.63        |
# |    explained_variance   | 0.441        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 467          |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00428     |
# |    value_loss           | 899          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 5.9e+04     |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 40          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.004800222 |
# |    clip_fraction        | 0.0173      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.573      |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 351         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 1.09e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.5e+04       |
# |    ep_rew_mean          | 5.9e+04       |
# | time/                   |               |
# |    fps                  | 773           |
# |    iterations           | 41            |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00093755045 |
# |    clip_fraction        | 0.00454       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.553        |
# |    explained_variance   | 0.346         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 823           |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.00118      |
# |    value_loss           | 1.47e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.9e+04      |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 42           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0026572794 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.524       |
# |    explained_variance   | 0.312        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 782          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00316     |
# |    value_loss           | 1.51e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 5.9e+04     |
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 43          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.002272931 |
# |    clip_fraction        | 0.0217      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.502      |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03e+03    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00259    |
# |    value_loss           | 1.8e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.5e+04    |
# |    ep_rew_mean          | 5.9e+04    |
# | time/                   |            |
# |    fps                  | 771        |
# |    iterations           | 44         |
# |    time_elapsed         | 116        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.00370186 |
# |    clip_fraction        | 0.0223     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.478     |
# |    explained_variance   | 0.22       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 877        |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00138   |
# |    value_loss           | 2.14e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.9e+04      |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 45           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0030401903 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.392       |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+03     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 2.36e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.9e+04      |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 46           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0025837594 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.387       |
# |    explained_variance   | 0.24         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43e+03     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 1.99e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.9e+04      |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 47           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0023310913 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.39        |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 898          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 1.89e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.9e+04      |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 48           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0011644824 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.391       |
# |    explained_variance   | 0.245        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 362          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00249     |
# |    value_loss           | 971          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.9e+04      |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 49           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0013997722 |
# |    clip_fraction        | 0.01         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.415       |
# |    explained_variance   | 0.304        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 346          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00169     |
# |    value_loss           | 640          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.9e+04      |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 50           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0058584763 |
# |    clip_fraction        | 0.00835      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.426       |
# |    explained_variance   | 0.285        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 259          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 955          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 5.9e+04      |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 51           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0013237809 |
# |    clip_fraction        | 0.00576      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.42        |
# |    explained_variance   | 0.342        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 340          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 593          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.25e+04     |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 52           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0011690091 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.383       |
# |    explained_variance   | 0.28         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 201          |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 451          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.25e+04     |
# | time/                   |              |
# |    fps                  | 768          |
# |    iterations           | 53           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0025538823 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.37        |
# |    explained_variance   | 0.206        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.5         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 215          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.25e+04     |
# | time/                   |              |
# |    fps                  | 768          |
# |    iterations           | 54           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0025023725 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.325       |
# |    explained_variance   | 0.403        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 268          |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 676          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.25e+04     |
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 55           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0012361178 |
# |    clip_fraction        | 0.00493      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.309       |
# |    explained_variance   | 0.432        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 283          |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.000447    |
# |    value_loss           | 529          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.25e+04     |
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 56           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0021327012 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.31        |
# |    explained_variance   | 0.481        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 351          |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00363     |
# |    value_loss           | 764          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# ...
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.189       |
# |    explained_variance   | 0.374        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 693          |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 1.88e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.44e+04     |
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 82           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0007858693 |
# |    clip_fraction        | 0.00884      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.219       |
# |    explained_variance   | 0.408        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 697          |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.000805    |
# |    value_loss           | 1.17e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.44e+04     |
# | time/                   |              |
# |    fps                  | 767          |
# |    iterations           | 83           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0006432347 |
# |    clip_fraction        | 0.00396      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.272       |
# |    explained_variance   | 0.425        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 428          |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 797          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.5e+04       |
# |    ep_rew_mean          | 6.44e+04      |
# | time/                   |               |
# |    fps                  | 768           |
# |    iterations           | 84            |
# |    time_elapsed         | 223           |
# |    total_timesteps      | 172032        |
# | train/                  |               |
# |    approx_kl            | 0.00045635135 |
# |    clip_fraction        | 0.0107        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.294        |
# |    explained_variance   | 0.397         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 396           |
# |    n_updates            | 830           |
# |    policy_gradient_loss | -0.00179      |
# |    value_loss           | 1.05e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.44e+04     |
# | time/                   |              |
# |    fps                  | 769          |
# |    iterations           | 85           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0013942432 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.289       |
# |    explained_variance   | 0.374        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 334          |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00196     |
# |    value_loss           | 771          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.56e+04     |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 86           |
# |    time_elapsed         | 228          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0016323328 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.306       |
# |    explained_variance   | 0.296        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 269          |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 630          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.56e+04     |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 87           |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0064958897 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.33        |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 125          |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 279          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.56e+04     |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 88           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0015677512 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.319       |
# |    explained_variance   | 0.435        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 184          |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 421          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.56e+04     |
# | time/                   |              |
# |    fps                  | 772          |
# |    iterations           | 89           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0018086719 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.283       |
# |    explained_variance   | 0.422        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 325          |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 636          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+04     |
# |    ep_rew_mean          | 6.56e+04    |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 90          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.001788616 |
# |    clip_fraction        | 0.0163      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.237      |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 344         |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 674         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.56e+04     |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 91           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0011214184 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.227       |
# |    explained_variance   | 0.51         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 470          |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 1.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.56e+04     |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 92           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0008386562 |
# |    clip_fraction        | 0.00894      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.252       |
# |    explained_variance   | 0.504        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 725          |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00185     |
# |    value_loss           | 1.25e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.56e+04     |
# | time/                   |              |
# |    fps                  | 775          |
# |    iterations           | 93           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0013344459 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | 0.479        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 818          |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 1.45e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.5e+04       |
# |    ep_rew_mean          | 6.56e+04      |
# | time/                   |               |
# |    fps                  | 776           |
# |    iterations           | 94            |
# |    time_elapsed         | 247           |
# |    total_timesteps      | 192512        |
# | train/                  |               |
# |    approx_kl            | 0.00094529625 |
# |    clip_fraction        | 0.00571       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.282        |
# |    explained_variance   | 0.5           |
# |    learning_rate        | 0.0003        |
# |    loss                 | 743           |
# |    n_updates            | 930           |
# |    policy_gradient_loss | -0.00142      |
# |    value_loss           | 1.52e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.56e+04     |
# | time/                   |              |
# |    fps                  | 777          |
# |    iterations           | 95           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0008099853 |
# |    clip_fraction        | 0.00688      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | 0.451        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+03     |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 2.18e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.56e+04     |
# | time/                   |              |
# |    fps                  | 777          |
# |    iterations           | 96           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0009633164 |
# |    clip_fraction        | 0.0085       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | 0.442        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 757          |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 1.76e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.56e+04     |
# | time/                   |              |
# |    fps                  | 778          |
# |    iterations           | 97           |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0007470915 |
# |    clip_fraction        | 0.00518      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | 0.495        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 930          |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.000926    |
# |    value_loss           | 1.74e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+04      |
# |    ep_rew_mean          | 6.56e+04     |
# | time/                   |              |
# |    fps                  | 779          |
# |    iterations           | 98           |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0009617509 |
# |    clip_fraction        | 0.00479      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.241       |
# |    explained_variance   | 0.437        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26e+03     |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 1.81e+03     |
# ------------------------------------------
# Training complete.
# Final profit with battery: 53,407.99 €
# ==================================================
# Final profit WITH battery (RL): €53,407.99
# ==================================================
# Battery efficiency: 0.9

# %%
# Save as interactive HTML in a file

#fig1.write_html("cumulative_profit.html")
#fig2.write_html("soc_over_time.html")
#fig3.write_html("market_prices_with_actions.html")
#fig4.write_html("distribution_of_prices.html")
fig6.write_html("total_soc_over_time.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       1 # Save as interactive HTML in a file
#       2
#       3 #fig1.write_html("cumulative_profit.html")
#       4 #fig2.write_html("soc_over_time.html")
#       5 #fig3.write_html("market_prices_with_actions.html")
#       6 #fig4.write_html("distribution_of_prices.html")
# ----> 7 fig6.write_html("total_soc_over_time.html")
#
# NameError: name 'fig6' is not defined

# %% [markdown]
# 2024 fisrt training
# ==================================================
# Final profit WITH battery (RL): €54,577.66
# ==================================================
# 2024
# ==================================================
# Final profit WITH battery (RL): €54,255.55
# ==================================================
